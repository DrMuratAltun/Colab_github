# %% [markdown]
# <a href="https://colab.research.google.com/github/DrMuratAltun/ECS-DS-6-25/blob/main/Bing_Image_Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download('cat',limit=100)
# Out:
# [%] Downloading Images to /content/dataset/cat
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 87 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://animalcorner.org/wp-content/uploads/2015/02/british-wild-cat-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://site-547756.mozfiles.com/files/547756/medium/catoutside.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.natgeofe.com/n/548467d8-c5f1-4551-9f58-6817a8d2c45e/NationalGeographic_2572187_16x9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://upload.wikimedia.org/wikipedia/commons/d/d4/Cat_March_2010-1a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://c.pxhere.com/photos/88/8a/cat_lying_blue_eye_small_ginger_fur_heal_pet_animal-609263.jpg!d
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.rd.com/wp-content/uploads/2023/05/GettyImages-1341465008.jpg
# [%] File Downloaded !
#
# ...

# %%
ls
# Out:
# dataset/  sample_data/

# %%
#klasörü taşı

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mv /content/dataset/ /content/drive/MyDrive/

# %%
# parametreleren görselleri indireceği klasörü belirlemeke
downloader.download('dog',
                    limit=100, output_dir=r"/content/drive/MyDrive/Colab Notebooks/ECS_VeriBilimi_25H/")
# Out:
# [%] Downloading Images to /content/drive/MyDrive/Colab Notebooks/ECS_VeriBilimi_25H/dog
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 64 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://static3.businessinsider.com/image/5484d9d1eab8ea3017b17e29/9-science-backed-reasons-to-own-a-dog.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.ctfassets.net/m5ehn3s5t7ec/wp-image-197645/ebb53a9acfebebaf0b7cdfd540ff6040/Jack-Russell-Terrier-Dog-Breed-Information.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://bebusinessed.com/wp-content/uploads/2014/03/734899052_13956580111.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://wagbrag.com/wp-content/uploads/2016/04/dog-1194077_1280.jpg
# [!] Issue getting: https://wagbrag.com/wp-content/uploads/2016/04/dog-1194077_1280.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #4 from http://www.insidedogsworld.com/wp-content/uploads/2016/03/Dog-Pictures.jpg
# ...
