# %% [markdown]
# <a href="https://colab.research.google.com/github/DrMuratAltun/ECS-DS-6-25/blob/main/Finans_Verileri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import yfinance as yf

# %%
google=yf.Ticker("GOOGL")
df=google.history(start="2020-01-01",
                  end="2025-07-11")

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-02 00:00:00-05:00   67.018569   68.026024   66.923141   68.026024
# 2020-01-03 00:00:00-05:00   66.998193   68.278016   66.964392   67.670158
# 2020-01-06 00:00:00-05:00   67.178606   69.499192   67.147300   69.473846
# 2020-01-07 00:00:00-05:00   69.605560   69.756654   69.163213   69.339653
# 2020-01-08 00:00:00-05:00   69.325228   70.171653   69.216384   69.833183
# ...                               ...         ...         ...         ...
# 2025-07-03 00:00:00-04:00  178.500000  179.669998  177.050003  179.529999
# 2025-07-07 00:00:00-04:00  179.059998  179.300003  175.679993  176.789993
# 2025-07-08 00:00:00-04:00  177.850006  177.949997  172.809998  174.360001
# 2025-07-09 00:00:00-04:00  175.250000  179.440002  172.770004  176.619995
# 2025-07-10 00:00:00-04:00  175.630005  178.429001  174.649994  178.100006
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df['Close'].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
nvda=yf.Ticker("NVDA")
df=nvda.history(start="2020-01-01",
                  end="2025-07-11")

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].max()
# Out:
# 164.02000427246094

# %%
df2=yf.download(["NVDA","INTC"],
                start="2015-1-1",
                end="2025-07-11")
# Out:
# /tmp/ipython-input-21-3081897642.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df2=yf.download(["NVDA","INTC"],
# [*********************100%***********************]  2 of 2 completed

# %%
df2['Close'].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>
